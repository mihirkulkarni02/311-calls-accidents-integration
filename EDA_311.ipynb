# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the dataset
file_path = 'final_311.csv'
data = pd.read_csv(file_path)

# Displaying the first few rows of the dataset to understand its structure
data.head()
# Out:
#    Unnamed: 0  Unique Key       Complaint Type               Descriptor  \
# 0           7    35136925  Noise - Residential             Loud Talking
# 1          50    35138249             PLUMBING                   TOILET
# 2          71    35144530     Dirty Conditions     E1 Improper Disposal
# 3         141    35143099  Noise - Residential         Loud Music/Party
# 4         160    35144027     Dirty Conditions  E2 Receptacle Violation
#
#                 Location Type  Zipcodes        Date      Time
# 0  Residential Building/House   10099.0  2016-12-31  23:50:22
# 1        RESIDENTIAL BUILDING   10092.0  2016-12-31  22:57:20
# 2                    Sidewalk   10099.0  2016-12-31  22:36:00
# 3  Residential Building/House   10099.0  2016-12-31  20:46:38
# 4                    Sidewalk   10099.0  2016-12-31  20:17:00

# %%
data.describe()
# Out:
#           Unnamed: 0    Unique Key      Zipcodes
# count   13842.000000  1.384200e+04  13842.000000
# mean   269459.308337  3.368069e+07  10094.697515
# std    154121.154557  8.395575e+05      4.141686
# min         7.000000  3.230529e+07  10090.000000
# 25%    130688.000000  3.297593e+07  10090.000000
# 50%    280093.000000  3.358682e+07  10092.000000
# 75%    403506.750000  3.443060e+07  10099.000000
# max    527954.000000  5.376378e+07  10100.000000

# %%
# Visualizing the distribution of complaint types
plt.figure(figsize=(10, 6))
data['Complaint Type'].value_counts().head(10).plot(kind='barh')
plt.title('Top 10 Complaint Types')
plt.xlabel('Frequency')
plt.ylabel('Complaint Type')
plt.tight_layout()
plt.show()

# Converting 'Date' column to datetime for time series analysis
data['Date'] = pd.to_datetime(data['Date'])

# Frequency of complaints over time
plt.figure(figsize=(12, 6))
data['Date'].value_counts().sort_index().plot()
plt.title('Frequency of Complaints Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Complaints')
plt.tight_layout()
plt.show()

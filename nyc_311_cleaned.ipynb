# %%
import pandas as pd


df = pd.read_csv('nyc_311.csv')

df['Created Date'] = pd.to_datetime(df['Created Date'])

df['Date'] = df['Created Date'].dt.date

df['Time'] = df['Created Date'].dt.time

df = df.drop('Created Date', axis =1)

df
# Out:
# /var/folders/qn/c3zq4pgs6md9gxx6rpp6k77c0000gn/T/ipykernel_58456/2362634017.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Created Date'] = pd.to_datetime(df['Created Date'])
#         Unique Key              Complaint Type          Descriptor  \
# 0         35137497            Derelict Vehicle  With License Plate
# 1         35136949         Noise - Residential    Loud Music/Party
# 2         35140076         Noise - Residential        Loud Talking
# 3         35138375         Noise - Residential    Loud Music/Party
# 4         35141923  Homeless Person Assistance                 NaN
# ...            ...                         ...                 ...
# 527951    32311692                      Rodent        Rat Sighting
# 527952    32312944                      Rodent        Rat Sighting
# 527953    32312027                      Rodent        Rat Sighting
# 527954    32310860                      Rodent        Rat Sighting
# 527955    32310788                      Rodent      Mouse Sighting
#
#                      Location Type  Zip Codes        Date      Time
# 0                  Street/Sidewalk    11729.0  2016-12-31  23:58:26
# 1       Residential Building/House    13098.0  2016-12-31  23:56:41
# 2       Residential Building/House    12075.0  2016-12-31  23:56:34
# 3       Residential Building/House    13090.0  2016-12-31  23:55:01
# 4                  Street/Sidewalk    12079.0  2016-12-31  23:54:55
# ...                            ...        ...         ...       ...
# 527951     3+ Family Apt. Building    12426.0  2016-01-01  00:00:00
# 527952           Catch Basin/Sewer    12423.0  2016-01-01  00:00:00
# 527953     3+ Family Apt. Building    12428.0  2016-01-01  00:00:00
# 527954     3+ Family Apt. Building    10099.0  2016-01-01  00:00:00
# 527955     3+ Family Apt. Building    12426.0  2016-01-01  00:00:00
#
# [527956 rows x 7 columns]

# %%
df.to_csv("final_311.csv")
